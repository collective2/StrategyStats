# %% [markdown]
# # Content

# %% [markdown]
# [Introduction](./Mtrc01_Doc_Introduction.ipynb)
#
# [Data Preparation](./Mtrc01_Doc_DataPreparation.ipynb)
#
# [Life And Death](./Mtrc01_Doc_LifeAndDeath.ipynb)
#
# [Population Statistics and Metric](./Mtrc01_Doc_PopulationStats.ipynb)
#
#
# ### Experiments - weekly statistics (C2 data)
#
# - [Age Strategy (Days)](./Mtrc01_Ages.ipynb)
# - [Alpha](./Mtrc01_Alpha.ipynb)
# - [Annualized Return Pcnt](./Mtrc01_AnnReturn.ipynb)
# - [Beta](./Mtrc01_Beta.ipynb)
# - [C2Star](./Mtrc01_C2Star.ipynb)
# - [Correlation to SP500](./Mtrc01_Correlation_to_SP500.ipynb)
# - [Cumul Return Pcnt](./Mtrc01_CumRtndefault.ipynb)
# - [Current Slump as Pcnt Equity](./Mtrc01_CurrentSlumpAsPcnt.ipynb)
# - [Daily Max Leverage (Avg)](./Mtrc01_DailyMaxLevMean.ipynb)
# - [Delta Equity 30 Days](./Mtrc01_Deltaequityp30.ipynb)
# - [Delta Equity 45 Days](./Mtrc01_Deltaequityp45.ipynb)
# - [Delta Equity 90 Days](./Mtrc01_Deltaequityp90.ipynb)
# - [JCalmar](./Mtrc01_JCalmar.ipynb)
# - [Avg(MAE) / Avg(PL) - Losers](./Mtrc01_MAEtoPL_agg_lose.ipynb)
# - [Avg(MAE) / Avg(PL) - Winners](./Mtrc01_MAEtoPL_agg_win.ipynb)
# - [Keep After Spread Slippage Percent (every fill pays bid/ask slippage)](./Mtrc01_KeepAfterSlip.ipynb)
# - [Latest Trade Days Ago](./Mtrc01_LatestTradeDaysAgo.ipynb)
# - [MaxDrawdown](./Mtrc01_MaxDrawdown.ipynb)
# - [Max Equity Drawdown (num days)](./Mtrc01_MaxdrawdownDays.ipynb)
# - [Max Open Loss Percent 45 Days](./Mtrc01_MaxOpenLossDays45.ipynb)
# - [Max Open Loss Percent 90 Days](./Mtrc01_MaxOpenLossDays90.ipynb)
# - [Max Open Loss Percent 180 Days](./Mtrc01_MaxOpenLossDays180.ipynb)
# - [Num Trades All](./Mtrc01_NumTradesAll.ipynb)
# - [Option Percent](./Mtrc01_OptionPercent.ipynb)
# - [Percentage Months Profitable](./Mtrc01_PcntMonthsProfit.ipynb)
# - [Percent returns kept after throwing out best month](./Mtrc01_PcntWithoutBestMonth.ipynb)
# - [Percent Trades Stocks,...](./Mtrc01_InstrumentsPercent.ipynb)
# - [Last 4 Months - Pcnt Negative](./Mtrc01_Pcnt_last4Mo_neg.ipynb)
# - [Sharpe Ratio](./Mtrc01_Sharpe.ipynb)
# - [Short Options - Percent Covered](./Mtrc01_ShortOptionsCovered.ipynb)
# - [Sortino Ratio](./Mtrc01_Sortino.ipynb)
# - [TimeSinceHigh_pctAge](./Mtrc01_TimeSinceHigh_pctAge.ipynb)
#
# [Why age is so important](./Mtrc01_Doc_Math.ipynb)
#
#
# <!---
#
# ### Experiments results
#
# - [ROC 7, 14, 21 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_007-021.html)
# - [ROC 30, 60, 90 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_030-090.html)
# - [ROC 120, 150, 180 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_120-180.html)
# - [ROC 210, 240, 270 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_210-270.html)
# - [ROC 300, 330, 360 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_300-360.html)
#
#
# ### Usage
#
# [Usage](Mtrc01_Doc_Usage01.ipynb)
#
#
# #### Tools
#
# [Experiments results](./Mtrc01_Doc_ExperimentsResults.ipynb)
#
#
#
# ### ToDo:
#
# - Carlton data
# - Model based score
#
# ### Not yet finished drafts: Experiments - daily statistics
#
# - [Annual return](Mtrc01_AnnReturnDaily.ipynb)
# - [Sharpe](Mtrc01_SharpeDaily.ipynb)
# - [Sortino](Mtrc01_SortinoDaily.ipynb)
# -->
#
# <!---
#
# ### ToDo:
#
# - [C2ScoreCarlton](./C2ScoreCarlton.ipynb)
# - [BobScoreCalmarDraft](./BobScoreCalmarDraft.ipynb)
# - [C2ScoreLinRegRSquared](./C2ScoreLinRegRSquared.ipynb)
# - [C2ScoreProfitDivMaxdd](./C2ScoreProfitDivMaxdd.ipynb)
#
#
# Mtrc01_Sharpe-Investigation-Details.ipynb
#
#
# - [BobScoreDescription](./BobScoreDescription.ipynb)
#
#
# private
#
# - [VaR_gaussian](./C2ScoreVar_gaussian.ipynb)
# - [VaR_historical](./C2ScoreVaR_historical.ipynb)
# - [Var_modified](./C2ScoreVar_modified.ipynb)
# - [jen jsem neco zacal okolo Collective2 Sharpe](./Untitled1.ipynb)
#
# private [MonthlyPopulationStats](./Mtrc01_MonthlyPopulationStats.ipynb)
#
# private [LiveAndDeadSystems_deprecated_failed_investigation](./LiveAndDeadSystems_deprecated_failed_investigation.ipynb)
#
# private [Part1_deprecated](./C2ScorePart1_deprecated.ipynb)
#
# private [Part2Daily](./C2ScorePart2Daily.ipynb)
#
# private [Part3-Copy1](./C2ScorePart3-Copy1.ipynb)
#
# private [Mtrc01_Doc_Learning_HypothesisTests_PrivateDoc.ipynb](./Mtrc01_Doc_Learning_HypothesisTests_PrivateDoc.ipynb)
#
# private [PopulationBasicSelectionByAge](./Mtrc01_PopulationBasicSelectionByAge.ipynb)
#
# private Mtrc01_UnitTest.ipynb
#
# private  [C2ScoreProfitDivMaxdd](C2ScoreProfitDivMaxdd.ipynb)
#
# -->
